# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn import model_selection
import warnings
warnings.filterwarnings("ignore")

# %%
datatrain= pd.read_csv('C:/Users/Arthur/Desktop/DataScienceCours/Machine learning/Titanic/train1.csv')

# %%
datatrain.drop(datatrain.columns[0], axis = 1, inplace = True)

# %%
data= pd.read_csv('C:/Users/Arthur/Desktop/DataScienceCours/Machine learning/Titanic/train3.csv')

# %%
datatrain = data[['PassengerId','Survived','Female','Boy','NTicket','TicketSurv']]
datatrain.head()
# Out:
#    PassengerId  Survived  Female    Boy  NTicket  TicketSurv
# 0            1         0   False  False        0         0.0
# 1            2         1    True  False        1         1.0
# 2            3         1    True  False        1         1.0
# 3            4         1    True  False        1         0.5
# 4            5         0   False  False        0         0.0

# %%
#Models to test
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
#evaluate performances
from sklearn.metrics import make_scorer, accuracy_score 
from sklearn.model_selection import GridSearchCV

# %%
X = datatrain.drop(labels=["Survived","PassengerId"], axis=1) #define training features set
y = datatrain["Survived"] #define training label set

# %%
#Simple separation between training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                            test_size=0.2, random_state=0, stratify = y)

# %%
#Creating cross validation data splits
cv_sets = model_selection.StratifiedShuffleSplit(n_splits = 3, test_size = 0.20, random_state = 5)
cv_sets.get_n_splits(X_train, y_train)
# Out:
# 3

# %%
svc_clf = SVC() 

parameters_svc = {"kernel": ["rbf", "linear"], "probability": [True, False]}

grid_svc = GridSearchCV(svc_clf, parameters_svc, scoring=make_scorer(accuracy_score), cv = cv_sets)
grid_svc.fit(X_train, y_train)

svc_clf = grid_svc.best_estimator_

svc_clf.fit(X_train, y_train)
pred_svc = svc_clf.predict(X_test)
acc_svc = accuracy_score(y_test, pred_svc)
print("The Score for SVC is: " + str(acc_svc))
grid_svc.best_params_
# Out:
# The Score for SVC is: 1.0
# {'kernel': 'linear', 'probability': True}

# %%
linsvc_clf = LinearSVC()

parameters_linsvc = {"fit_intercept": [True, False], "max_iter": [100, 500, 1000, 1500]}

grid_linsvc = GridSearchCV(linsvc_clf, parameters_linsvc, scoring=make_scorer(accuracy_score), cv = cv_sets)
grid_linsvc.fit(X_train, y_train)

linsvc_clf = grid_linsvc.best_estimator_

linsvc_clf.fit(X_train, y_train)
pred_linsvc = linsvc_clf.predict(X_test)
acc_linsvc = accuracy_score(y_test, pred_linsvc)

print("The Score for LinearSVC is: " + str(acc_linsvc))
grid_linsvc.best_params_
# Out:
# The Score for LinearSVC is: 1.0
# {'fit_intercept': True, 'max_iter': 100}

# %%
#DecisionTreeClassifier 
DT_clf = DecisionTreeClassifier()

parameters_dt = {"max_depth": [2, 3, 5, 10],"min_samples_split": [2, 3, 5, 10], "max_features": ["auto", "sqrt", "log2"],
                 "criterion": ["gini"] }

grid_dt = GridSearchCV(DT_clf, parameters_dt, scoring=make_scorer(accuracy_score), cv = cv_sets, verbose = True)
grid_dt.fit(X_train, y_train)

DT_clf = grid_dt.best_estimator_

DT_clf.fit(X_train, y_train)
pred_dt = DT_clf.predict(X_test)
acc_dt = accuracy_score(y_test, pred_dt)

print("The Score for DecisionTree is: " + str(acc_dt))
grid_dt.best_params_
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# The Score for DecisionTree is: 0.9888268156424581
# [Parallel(n_jobs=1)]: Done 144 out of 144 | elapsed:    0.6s finished
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'min_samples_split': 3}

# %%
# Random Forest
rf_clf = RandomForestClassifier()

parameters_rf = {"n_estimators": [4, 5, 6, 7, 8, 9, 10, 15], "criterion": ["gini", "entropy"], "max_features": ["auto", "sqrt", "log2"], 
                 "max_depth": [2, 3, 5, 10], "min_samples_split": [2, 3, 5, 10]}

grid_rf = GridSearchCV(rf_clf, parameters_rf, scoring=make_scorer(accuracy_score), cv = cv_sets)
grid_rf.fit(X_train, y_train)

rf_clf = grid_rf.best_estimator_

rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_test)
acc_rf = accuracy_score(y_test, pred_rf)

print("The Score for Random Forest is: " + str(acc_rf))
grid_rf.best_params_
# Out:
# The Score for Random Forest is: 0.994413407821229
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'min_samples_split': 3,
#  'n_estimators': 5}

# %%
#Logistic Regression 
logreg_clf = LogisticRegression()

parameters_logreg = {'C': np.logspace(0, 1, 5), "penalty": ["l2"], "fit_intercept": [True, False], "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
                     "max_iter": [50, 100, 200]}

grid_logreg = GridSearchCV(logreg_clf, parameters_logreg, scoring=make_scorer(accuracy_score), cv = cv_sets)
grid_logreg.fit(X_train, y_train)

logreg_clf = grid_logreg.best_estimator_

logreg_clf.fit(X_train, y_train)
pred_logreg = logreg_clf.predict(X_test)
acc_logreg = accuracy_score(y_test, pred_logreg)

print("The Score for Logistic Regression is: " + str(acc_logreg))
grid_logreg.best_params_
# Out:
# The Score for Logistic Regression is: 1.0
# {'C': 1.0,
#  'fit_intercept': True,
#  'max_iter': 50,
#  'penalty': 'l2',
#  'solver': 'newton-cg'}

# %%
#KNeighbors Classifier
knn_clf = KNeighborsClassifier()

parameters_knn = {"n_neighbors": [3, 5, 10, 15], "weights": ["uniform", "distance"], "algorithm": ["auto", "ball_tree", "kd_tree"],
                  "leaf_size": [20, 30, 50]}

grid_knn = GridSearchCV(knn_clf, parameters_knn, scoring=make_scorer(accuracy_score), cv = cv_sets)
grid_knn.fit(X_train, y_train)

knn_clf = grid_knn.best_estimator_

knn_clf.fit(X_train, y_train)
pred_knn = knn_clf.predict(X_test)
acc_knn = accuracy_score(y_test, pred_knn)

print("The Score for KNeighbors is: " + str(acc_knn))
grid_knn.best_params_
# Out:
# The Score for KNeighbors is: 1.0
# {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'weights': 'uniform'}

# %%
#AdaBoost
AB_clf = AdaBoostClassifier(n_estimators = 200, random_state = 2)
parameters_AB = {'learning_rate': np.linspace(0.5, 2, 5)}
grid_ab = GridSearchCV(AB_clf, parameters_AB, scoring=make_scorer(accuracy_score), cv = cv_sets)
grid_ab.fit(X_train, y_train)

AB_clf = grid_ab.best_estimator_
pred_ab = AB_clf.predict(X_test)
acc_ab = accuracy_score(y_test, pred_ab)

grid_ab.best_params_
print("The Score for AdaBoost is: " + str(acc_ab))
grid_ab.best_params_
# Out:
# The Score for AdaBoost is: 0.994413407821229
# {'learning_rate': 0.5}

# %%
#GaussianNB
GNB_clf = GaussianNB()
GNB_clf.fit(X_train,y_train)

pred_gnb = GNB_clf.predict(X_test)
acc_gnb = accuracy_score(y_test, pred_gnb)


print("The Score for GaussianNB is: " + str(acc_gnb))
# Out:
# The Score for GaussianNB is: 0.9441340782122905

# %%
#Ensemble method : 
from sklearn.ensemble import VotingClassifier
ensemble_lin_rbf=VotingClassifier(estimators=[('KNN',knn_clf),
                                              ('RBF',svc_clf),
                                              ('RFor',rf_clf),
                                              ('LR',logreg_clf),
                                              ('DT',DT_clf),
                                              ('NB',GaussianNB())], voting='soft').fit(X_train,y_train)
print('The accuracy for ensembled model is:',ensemble_lin_rbf.score(X_test,y_test))
# Out:
# The accuracy for ensembled model is: 1.0

# %%
#Printing the predictions (CSV file) for the best model
bestmodel = DT_clf
rawtest = pd.read_csv('C:/Users/Arthur/Desktop/DataScienceCours/Machine learning/Titanic/raw_test.csv')
datatest= pd.read_csv('C:/Users/Arthur/Desktop/DataScienceCours/Machine learning/Titanic/test3.csv')
datatest
# Out:
#      Unnamed: 0  PassengerId  Pclass  Sex   Age  Size  Q  S  (1, 5]  (5, 10]  \
# 0             0          892       3    0  34.5   0.0  1  0       0        1
# 1             1          893       3    1  47.0   1.0  0  1       0        0
# 2             2          894       2    0  62.0   0.0  1  0       0        1
# 3             3          895       3    0  27.0   0.0  0  1       0        0
# 4             4          896       3    1  22.0   1.0  0  1       0        1
# 5             5          897       3    0  14.0   0.0  0  1       0        1
# 6             6          898       3    1  30.0   0.0  1  0       0        0
# 7             7          899       2    0  26.0   1.0  0  1       0        0
# 8             8          900       3    1  18.0   0.0  0  0       0        0
# 9             9          901       3    0  21.0   1.0  0  1       0        0
# 10           10          902       3    0  21.0   0.0  0  1       0        0
# ...

# %%
testemp = datatest.drop(datatest.columns[0], axis =1)
test = data[['PassengerId','Female','Boy','NTicket','TicketSurv']]
test = test.drop('PassengerId', axis =1)
test
# Out:
#      Female    Boy  NTicket  TicketSurv
# 0     False  False        0        0.00
# 1      True  False        1        1.00
# 2      True  False        1        1.00
# 3      True  False        1        0.50
# 4     False  False        0        0.00
# 5     False  False        0        0.00
# 6     False  False        0        0.00
# 7     False   True        4        0.00
# 8      True  False        3        1.00
# 9      True  False        1        0.50
# 10     True  False        2        1.00
# 11     True  False        1        1.00
# 12    False  False        0        0.00
# 13    False  False        6        0.00
# 14     True  False        1        0.00
# 15     True  False        1        1.00
# 16    False   True        5        0.00
# 17    False  False        0        1.00
# 18     True  False        2        0.00
# 19     True  False        1        1.00
# 20    False  False        0        0.00
# 21    False  False        0        1.00
# ...

# %%
results = pd.DataFrame(bestmodel.predict(test))
results
# Out:
#      0
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# 10   1
# 11   1
# 12   0
# 13   0
# 14   0
# 15   1
# 16   0
# 17   1
# 18   0
# 19   1
# 20   0
# 21   1
# 22   1
# 23   1
# 24   0
# 25   1
# 26   0
# 27   0
# 28   1
# 29   0
# ..  ..
# 861  0
# 862  1
# 863  0
# 864  0
# 865  1
# 866  1
# 867  0
# 868  0
# 869  1
# 870  0
# 871  1
# 872  0
# 873  0
# 874  1
# 875  1
# 876  0
# 877  0
# 878  0
# 879  1
# 880  1
# 881  0
# 882  0
# 883  0
# 884  0
# 885  0
# 886  0
# 887  1
# 888  0
# 889  1
# 890  0
#
# [891 rows x 1 columns]

# %%
result=pd.DataFrame()
result['PassengerId'] = rawtest['PassengerId']
result['Survived'] = results[0]
result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         1
# 3            895         1
# 4            896         0
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         1
# 10           902         1
# 11           903         1
# 12           904         0
# 13           905         0
# 14           906         0
# 15           907         1
# 16           908         0
# 17           909         1
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         1
# 24           916         0
# 25           917         1
# 26           918         0
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         1
# ...

# %%
result.to_csv('result2.csv',header = True, sep = ',', encoding = 'utf-8', index = False)
